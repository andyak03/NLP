# %% [markdown]
# # Информационный поиск
#
# __Автор задач: Блохин Н.В. (NVBlokhin@fa.ru)__
#
# Материалы:
# * https://nlp.stanford.edu/~manning/xyzzy/Intro_Inform_Retrieval_Russian.pdf
# * https://en.wikipedia.org/wiki/Jaccard_index
# * https://en.wikipedia.org/wiki/TF-IDF
# * https://en.wikipedia.org/wiki/Okapi_BM25

# %% [markdown]
# ## Задачи для совместного разбора

# %% [markdown]
# 1\. Дан корпус текстов. Построить прямой и обратный индексы для слов из текста

# %%
corpus = [
    "Первым специальным индексом для запросов с джокером общего вида является перестановочный индекс",
    "Методы усовершенствования индексов для расширения функциональных возможностей и повышения скорости поиска"
]

# %%
# !pip install pymorphy2

# %%
from nltk import word_tokenize

import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import pymorphy2

morph = pymorphy2.MorphAnalyzer()

# %%
index = {}
for idx, doc in enumerate(corpus):
  index[idx] = [
    morph.parse(w)[0].normal_form
    for w in word_tokenize(doc)
  ]

# %%
index

# %%
from collections import defaultdict
# inv_index = defaultdict(list)
inv_index = defaultdict(set)

# defaultdict(f)
# if k not in d:
# d[k] = f() # list()

for idx, tokens in index.items():
  for tok in tokens:
    inv_index[tok].add(idx)

# %% [markdown]
# 2\. Посчитать индекс Жаккара для предложений из заданного корпуса.

# %%
index[0]
# Out:
# ['первый',
#  'специальный',
#  'индекс',
#  'для',
#  'запрос',
#  'с',
#  'джокер',
#  'общий',
#  'вид',
#  'являться',
#  'перестановочный',
#  'индекс']

# %%
index[1]
# Out:
# ['метод',
#  'усовершенствование',
#  'индекс',
#  'для',
#  'расширение',
#  'функциональный',
#  'возможность',
#  'и',
#  'повышение',
#  'скорость',
#  'поиск']

# %%
(
    len(set(index[0]).intersection(set(index[1]))),
    len(set(index[0]).union(set(index[1])))
)
# Out:
# (2, 20)

# %% [markdown]
# ## Задачи для самостоятельного решения

# %%
import json
import nltk
from nltk import word_tokenize
import pymorphy2
from collections import defaultdict
from collections import Counter
from math import log
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ma2si\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# <p class="task" id="1"></p>
#
# ### 1
# Считайте тексты новостей из файла `news.json`. Назовём прямым индексом словарь, где ключами являются номера новостей, а значениями - списки нормализованных слов, входящих в эту новость. Номер новости определяется ее положением в файле. Назовём обратным индексом словарь, где ключами являются нормальные формы слов, а значениями - множества номеров новостей, которые содержат данное слово (не обязательно в нормальной форме). Постройте прямой и обратный индекс. Выведите из длины на экран. Выведите значения обратного индекса по ключу "москва".

# %% [markdown]
# - [x] Проверено на семинаре

# %%
with open('data/news.json', 'r', encoding='utf8') as f:
    corpus = json.load(f)

# %%
print(corpus)
# Out:
# ['российский бюджет в марте недополучил более 300 миллиардов рублей нефтегазовых доходов', 'банк россии решил снизить ключевую ставку с 20  до 17 ', 'мыс идокопас  в нато назвали первую цель для начала полномасштабного вторжения в россию ', 'минобороны рф заявило об ударах ракетами «калибр» по запорожскому алюминиевому комбинату и уничтожении ангаров с иностранным оружием', 'госдеп попросил россию исключить санта клауса из санкционного списка на время рождественских праздников ', 'я ее не трогал распустивший язык пригожин отпихнул от себя оскандалившуюся вайкуле', 'приложение «аэрофлота» больше недоступно в app store', 'виталий милонов награждён высшим венгерским орденом за борьбу с гомосексуализмом ', '«яндекс еду» наказали за утечку адресов  телефонов и имен десятков тысяч клиентов  суд назначил минимально возможный штраф — 60 тысяч рублей', 'трамп предложил перенести новые санкции против россии из за дня народного единства ', 'афганистан  присоединение кабула к санкциям против москвы   не повод для сокращения российской гумпомощи ', 'рейтинг хонеккера в германии достиг исторического максимума ', 'собянин рассказал о стоимости вакцинации от коронавируса', 'трамп предложит ким чен ыну воспользоваться программой защиты свидетелей ', 'папа римский подарил путину щенка ', 'чернокожий мужчина напал на работниц прачечной с ручной пилой и попал на видео', 'канадский ку клукс клан потребовал от джастина трюдо подать в отставку из за скандала с блэкфейсом ', 'венгрия пригрозила заблокировать попытки ес расширить запрет на импорт российских энергоносителей', 'игорь коротченко  «дали американцам пинок под зад» ', 'анджелина джоли раздала африканским детям пшеничное зерно ', 'еспч обязал россию выплатить жителю латвии 6 млн евро за пребывание в гулаге в 1975 1978 годах ', 'горбачёв поддержал отстранение россии от олимпиады ', 'россия объявила о высылке 45 польских дипломатов', 'старая аферистка фанерщица солнцев разоблачил жульничество ревматоидной аллегровой', 'порошенко обвинили в незаконном получении трех миллиардов долларов', 'великобритания ввела санкции против «камаза»  вгтрк и наили аскер заде', 'россия возобновит авиасообщение с 52 «дружественными» странами', 'рбк  дальневосточная авиакомпания «аврора» столкнулась с нехваткой самолетов', 'в москве участницу антивоенного митинга приговорили к двум годам колонии по делу о брошенной бутылке с «коктейлем молотова»  судя по видео  она ни в кого не попала', '«газпром» из за санкций лишился тысяч позиций офисной техники на сумму 12 млрд рублей', 'бюджетников пенсионеров и студентов обяжут обедать во «вкусно и точка» ', 'мид рф объявил о санкциях в отношении 398 конгрессменов сша и 87 сенаторов канады', 'автора канала «протестный мгу» арестовали на 10 суток в москве  накануне его задержали при выходе из университета', 'в донецкой области  по данным властей  за день от обстрелов погиб 21 мирный житель', 'в знаменной группе минобороны выявили провокаторов планировавших на параде победы бросить триколор к мавзолею ', 'эсминец uss zumwalt вошёл в российские воды чтобы дозвониться на прямую линию президента россии ', 'международную универсиаду 2023 года перенесут из екатеринбурга', 'фигурантов дела об убийстве главы ингушского центра «э» заподозрили в терроризме', 'путин подписал указ об ответных санкциях  он требует игнорировать действующие контракты и запрещает экспорт  кто попадет под санкции  пока неясно', 'япония намерена объединить курилы и хоккайдо с помощью океанского песка ', 'россия ведёт переговоры с мексикой о перезахоронении троцкого в кремлевской стене ', 'морщины и нет зубов фото постаревшей до отвращения бабкиной без фильтров и макияжа слили в сеть', 'россиянам раскрыли способ избежать ожирения в отпуcке', 'huawei удалила из своего магазина приложения российских втб  «открытия» и промсвязьбанка  попавших под санкции', 'дерипаска вспомнил рузвельта и назвал поправки к конституции «новым соглашением»', 'убиты горем беременная орлова пытается спасти ребенка', 'майя санду заявила ...

# %%
morph = pymorphy2.MorphAnalyzer()

# %%
index = {}
for idx, doc in enumerate(corpus):
  index[idx] = [
    morph.parse(w)[0].normal_form
    for w in word_tokenize(doc)
  ]
print(index)
# Out:
# {0: ['российский', 'бюджет', 'в', 'март', 'недополучить', 'более', '300', 'миллиард', 'рубль', 'нефтегазовый', 'доход'], 1: ['банк', 'россия', 'решить', 'снизить', 'ключевой', 'ставка', 'с', '20', 'до', '17'], 2: ['мыс', 'идокопас', 'в', 'нато', 'назвать', 'первый', 'цель', 'для', 'начало', 'полномасштабный', 'вторжение', 'в', 'россия'], 3: ['минобороны', 'рф', 'заявить', 'о', 'удар', 'ракета', '«', 'калибр', '»', 'по', 'запорожский', 'алюминиевый', 'комбинат', 'и', 'уничтожение', 'ангар', 'с', 'иностранный', 'оружие'], 4: ['госдеп', 'попросить', 'россия', 'исключить', 'сант', 'клаус', 'из', 'санкционный', 'список', 'на', 'время', 'рождественский', 'праздник'], 5: ['я', 'она', 'не', 'трогать', 'распустить', 'язык', 'пригожин', 'отпихнуть', 'от', 'себя', 'оскандалиться', 'вайкуль'], 6: ['приложение', '«', 'аэрофлот', '»', 'большой', 'недоступный', 'в', 'app', 'store'], 7: ['виталий', 'милон', 'наградить', 'высокий', 'венгерский', 'орден', 'за', 'борьба', 'с', 'гомосексуализм'], 8: ['«', 'яндекс', 'еда', '»', 'наказать', 'за', 'утечка', 'адрес', 'телефон', 'и', 'имя', 'десяток', 'тысяча', 'клиент', 'суд', 'назначить', 'минимально', 'возможный', 'штраф', '—', '60', 'тысяча', 'рубль'], 9: ['трамп', 'предложить', 'перенести', 'новый', 'санкция', 'против', 'россия', 'из', 'за', 'день', 'народный', 'единство'], 10: ['афганистан', 'присоединение', 'кабул', 'к', 'санкция', 'против', 'москва', 'не', 'повод', 'для', 'сокращение', 'российский', 'гумпомощь'], 11: ['рейтинг', 'хонеккер', 'в', 'германия', 'достигнуть', 'исторический', 'максимум'], 12: ['собянин', 'рассказать', 'о', 'стоимость', 'вакцинация', 'от', 'коронавирус'], 13: ['трамп', 'предложить', 'ким', 'чен', 'ыну', 'воспользоваться', 'программа', 'защита', 'свидетель'], 14: ['папа', 'римский', 'подарить', 'путин', 'щенок'], 15: ['чернокожий', 'мужчина', 'напасть', 'на', 'работница', 'прачечная', 'с', 'ручной', 'пила', 'и', 'попасть', 'на', 'видео'], 16: ['канадский', 'ку', 'клукс', 'клан', 'потребовать', 'от', 'джастин', 'трюдо', 'подать', 'в', 'отставка', 'из', 'за', 'скандал', 'с', 'блэкфейс'], 17: ['венгрия', 'пригрозить', 'заблокировать', 'попытка', 'ес', 'расширить', 'запрет', 'на', 'импорт', 'российский', 'энергоноситель'], 18: ['игорь', 'коротченко', '«', 'дать', 'американец', 'пинок', 'под', 'зад', '»'], 19: ['анджелина', 'джоля', 'раздать', 'африканский', 'ребёнок', 'пшеничный', 'зерно'], 20: ['еспча', 'обязать', 'россия', 'выплатить', 'житель', 'латвия', '6', 'млн', 'евро', 'за', 'пребывание', 'в', 'гулаг', 'в', '1975', '1978', 'год'], 21: ['горбачёв', 'поддержать', 'отстранение', 'россия', 'от', 'олимпиада'], 22: ['россия', 'объявить', 'о', 'высылка', '45', 'польский', 'дипломат'], 23: ['старый', 'аферистка', 'фанерщица', 'солнцев', 'разоблачить', 'жульничество', 'ревматоидный', 'аллегров'], 24: ['порошенко', 'обвинить', 'в', 'незаконный', 'получение', 'три', 'миллиард', 'доллар'], 25: ['великобритания', 'ввести', 'санкция', 'против', '«', 'камаз', '»', 'вгтрк', 'и', 'наиль', 'аскер', 'зад'], 26: ['россия', 'возобновить', 'авиасообщение', 'с', '52', '«', 'дружественный', '»', 'страна'], 27: ['рбк', 'дальневосточный', 'авиакомпания', '«', 'аврора', '»', 'столкнуться', 'с', 'нехватка', 'самолёт'], 28: ['в', 'москва', 'участница', 'антивоенный', 'митинг', 'приговорить', 'к', 'два', 'год', 'колония', 'по', 'дело', 'о', 'бросить', 'бутылка', 'с', '«', 'коктейль', 'молотов', '»', 'судить', 'по', 'видео', 'она', 'ни', 'в', 'кто', 'не', 'попасть'], 29: ['«', 'газпром', '»', 'из', 'за', 'санкция', 'лишиться', 'тысяча', 'позиция', 'офисный', 'техника', 'на', 'сумма', '12', 'млрд', 'рубль'], 30: ['бюджетник', 'пенсионер', 'и', 'студент', 'обязать', 'обедать', 'в', '«', 'вкусно', 'и', 'точка', '»'], 31: ['мид', 'рф', 'объявить', 'о', 'санкция', 'в', 'отношение', '398', 'конгрессмен', 'сша', 'и', '87', 'сенатор', 'канада'], 32: ['автор', 'канал', '«', 'протестный', 'мгу', '»', 'арестовать', 'на', '10', 'сутки', 'в', 'москва', 'накануне', 'он', 'задержать', 'при', 'выход', 'из', 'у ...

# %%
len(index)
# Out:
# 500

# %%
inv_index = defaultdict(list)

for idx, tokens in index.items():
  for tok in tokens:
    inv_index[tok].append(idx)

print(inv_index)
# Out:
# defaultdict(<class 'list'>, {'российский': [0, 10, 17, 35, 43, 48, 71, 81, 101, 104, 114, 122, 125, 129, 135, 151, 160, 167, 216, 219, 229, 254, 259, 266, 300, 301, 396, 399, 437, 442, 451, 456, 472], 'бюджет': [0, 204], 'в': [0, 2, 2, 6, 11, 16, 20, 20, 24, 28, 28, 30, 31, 32, 33, 34, 35, 37, 40, 41, 42, 50, 51, 52, 53, 58, 60, 63, 64, 66, 68, 70, 70, 72, 74, 77, 81, 82, 84, 86, 87, 88, 89, 91, 92, 93, 95, 96, 97, 103, 103, 108, 113, 113, 113, 116, 117, 118, 123, 123, 127, 130, 132, 133, 134, 135, 136, 136, 141, 148, 149, 153, 153, 154, 158, 158, 159, 161, 166, 168, 170, 171, 171, 173, 175, 176, 177, 178, 178, 178, 179, 182, 188, 188, 189, 189, 192, 199, 200, 201, 203, 205, 206, 213, 214, 215, 217, 218, 219, 221, 224, 225, 228, 229, 229, 230, 232, 234, 236, 238, 241, 243, 245, 246, 248, 249, 257, 258, 258, 259, 261, 261, 264, 265, 265, 266, 269, 273, 274, 276, 277, 278, 280, 282, 283, 284, 288, 289, 290, 292, 297, 300, 303, 304, 305, 307, 308, 309, 309, 313, 316, 318, 320, 324, 325, 325, 327, 329, 330, 330, 331, 334, 338, 341, 346, 349, 351, 352, 355, 355, 356, 356, 358, 358, 360, 364, 365, 365, 371, 373, 374, 374, 376, 379, 380, 382, 382, 383, 384, 386, 389, 391, 392, 393, 397, 399, 400, 402, 405, 410, 411, 415, 417, 426, 432, 438, 439, 444, 444, 445, 446, 449, 450, 451, 453, 458, 460, 463, 464, 464, 466, 473, 477, 478, 479, 482, 483, 485, 486, 486, 487, 490, 491, 492, 493, 493, 494, 495], 'март': [0], 'недополучить': [0], 'более': [0, 129, 145, 350, 381, 429], '300': [0], 'миллиард': [0, 24, 122, 144, 294, 395], 'рубль': [0, 8, 29, 119, 167, 224, 294, 395, 426, 431], 'нефтегазовый': [0], 'доход': [0], 'банк': [1, 348, 447], 'россия': [1, 2, 4, 9, 20, 21, 22, 26, 35, 40, 56, 59, 66, 72, 77, 91, 92, 105, 108, 127, 131, 137, 166, 168, 170, 178, 187, 195, 196, 197, 207, 210, 214, 217, 218, 220, 236, 243, 248, 249, 269, 270, 272, 276, 295, 298, 313, 316, 328, 329, 330, 331, 338, 339, 340, 342, 349, 351, 352, 355, 358, 366, 368, 383, 404, 415, 447, 454, 462, 490, 493, 496, 499], 'решить': [1, 154, 248], 'снизить': [1], 'ключевой': [1, 399], 'ставка': [1], 'с': [1, 3, 7, 15, 16, 26, 27, 28, 39, 40, 50, 51, 52, 63, 64, 68, 84, 99, 100, 106, 106, 150, 155, 189, 193, 195, 210, 216, 220, 221, 241, 241, 242, 243, 262, 263, 266, 285, 290, 304, 326, 328, 333, 334, 347, 351, 354, 356, 361, 364, 373, 383, 395, 403, 405, 413, 415, 416, 416, 428, 439, 443, 450, 450, 463, 468, 471, 492, 494, 495], '20': [1], 'до': [1, 41, 58, 69, 157, 211, 248, 336, 344, 381, 469, 489], '17': [1], 'мыс': [2, 274, 274], 'идокопас': [2], 'нато': [2, 146, 149, 243, 276, 324, 328], 'назвать': [2, 44, 250, 279, 281, 293, 347, 387, 425, 450, 467], 'первый': [2, 82, 96, 202, 208, 214, 236, 239, 266, 340, 355, 358, 365, 483], 'цель': [2], 'для': [2, 10, 46, 59, 73, 83, 139, 142, 152, 156, 177, 189, 191, 199, 204, 255, 286, 293, 308, 332, 375, 405, 415, 417, 434, 454, 459], 'начало': [2], 'полномасштабный': [2], 'вторжение': [2], 'минобороны': [3, 34, 173, 298, 413, 450, 466], 'рф': [3, 31, 115, 127, 145, 158, 171, 242, 271, 305, 422, 450, 466], 'заявить': [3, 46, 126, 151, 178, 209, 259, 268, 308, 352, 400, 433, 455, 484, 497], 'о': [3, 12, 22, 28, 31, 37, 38, 40, 48, 55, 66, 69, 77, 85, 90, 98, 109, 115, 123, 123, 125, 134, 144, 145, 151, 154, 178, 180, 184, 191, 192, 198, 209, 212, 221, 223, 227, 230, 236, 242, 254, 254, 265, 268, 269, 278, 283, 296, 298, 305, 306, 306, 330, 345, 346, 362, 366, 372, 395, 400, 409, 417, 420, 443, 445, 452, 455, 469, 475, 484, 493, 497, 498], 'удар': [3, 391, 477], 'ракета': [3, 357, 413, 464], '«': [3, 6, 8, 18, 25, 26, 27, 28, 29, 30, 32, 37, 43, 44, 50, 63, 66, 66, 74, 80, 80, 89, 91, 110, 111, 113, 114, 123, 126, 126, 130, 133, 139, 142, 144, 157, 157, 171, 173, 175, 180, 181, 182, 183, 184, 197, 201, 201, 207, 207, 208, 213, 217, 218, 221, 222, 222, 223, 224, 230, 233, 236, 237, 238, 240, 241, 241, 250, 251, 252, 254, 254, 260, 266, 274, 288, 290, 292, 305, 306, 316, 317, 317, 327, 346, 348, 350, 350, 359, 363, 366, 367, 370, 37 ...

# %%
len(inv_index)
# Out:
# 2443

# %%
print(inv_index['москва'])
# Out:
# [10, 28, 32, 88, 111, 134, 148, 176, 182, 190, 199, 205, 207, 225, 240, 275, 280, 297, 324, 350, 374, 416, 466, 486]

# %% [markdown]
# <p class="task" id="2"></p>
#
# ### 2
# Для каждого документа из текста определите, как часто слова этого документа встречаются в заданном тексте, воспользовавшись обратным индексом. Выведите на экран текст топ-3 новостей, наиболее похожих по набору токенов на заданный текст. Выведите на экран текст найденных новостей и количество совпадающих токенов.

# %% [markdown]
# - [x] Проверено на семинаре

# %%
example = "Жириновский предложил перенести столицу из Москвы"

# %%
example_tokens = []
for token in word_tokenize(example):
    example_tokens.append(morph.parse(token)[0].normal_form)
example_tokens
# Out:
# ['жириновский', 'предложить', 'перенести', 'столица', 'из', 'москва']

# %%
sents = []
for token in example_tokens:
    sents.extend(inv_index[token])

num_counts = Counter(sents)

sorted_counts = sorted(num_counts.items(), key=lambda x: x[1], reverse=True)

for num, count in sorted_counts[:3]:
    print(f"Новость {num} содержит {count} слова из example {index[num]}\nОбщие слова:  {set(index[num]).intersection(example_tokens)}\n")
# Out:
# Новость 9 содержит 3 слова из example ['трамп', 'предложить', 'перенести', 'новый', 'санкция', 'против', 'россия', 'из', 'за', 'день', 'народный', 'единство']
# Общие слова:  {'предложить', 'перенести', 'из'}
#
# Новость 78 содержит 2 слова из example ['31', 'декабрь', 'владимир', 'жириновский', 'предложить', 'имя', 'свой', 'преемник']
# Общие слова:  {'предложить', 'жириновский'}
#
# Новость 112 содержит 2 слова из example ['жириновский', 'предложить', 'дать', 'ремень', 'создатель', 'гачимучить', 'кавер', 'на', 'известный', 'песня']
# Общие слова:  {'предложить', 'жириновский'}

# %% [markdown]
# <p class="task" id="3"></p>
#
# ### 3
# Для заданного текста новости найдите топ-3 наиболее похожих новости, воспользовавшись коэффициентом Жаккара. Для определения количества общих слов в тексте используйте обратный индекс.  Выведите на экран текст найденных новостей и значение коэффициента Жаккара для каждой новости.

# %%
example = "Жириновский предложил перенести столицу из Москвы"

# %%
example_tokens = []
for token in word_tokenize(example):
    example_tokens.append(morph.parse(token)[0].normal_form)
example_tokens = set(example_tokens)    
example_tokens
# Out:
# {'жириновский', 'из', 'москва', 'перенести', 'предложить', 'столица'}

# %%
jaccard_scores = []

for i, text in index.items():
    text = set(text)
    intersection = len(example_tokens.intersection(text))
    union = len(example_tokens.union(text))
    jaccard_coefficient = intersection / union
    jaccard_scores.append((i, jaccard_coefficient))

jaccard_scores.sort(key=lambda x: x[1], reverse=True)
top_3_similar_news = jaccard_scores[:3]

for i, score in jaccard_scores[:3]:
    print(f"Новость {i} J = {score} {index[i]}\n")
# Out:
# Новость 9 J = 0.2 ['трамп', 'предложить', 'перенести', 'новый', 'санкция', 'против', 'россия', 'из', 'за', 'день', 'народный', 'единство']
#
# Новость 36 J = 0.18181818181818182 ['международный', 'универсиада', '2023', 'год', 'перенести', 'из', 'екатеринбург']
#
# Новость 270 J = 0.18181818181818182 ['токай', 'предложить', 'исключить', 'россия', 'из', 'состав', 'снг']

# %% [markdown]
# <p class="task" id="4"></p>
#
# ### 4
# Реализуйте функцию для расчета TF-IDF.
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
#
# Для расчета обратной частоты документа воспользуйтесь обратным индексом из предыдущей задачи. При расчете IDF добавьте сглаживание, прибавив единицу к числителю и знаменателю дроби.

# %%
def calculate_tfidf(word, text, index, inv_index):

    tf = (text.count(word)) / len(text)
    
    idf = log((len(index) + 1) / (len(inv_index[word])) + 1)
    
    tfidf = tf * idf
    
    return tfidf

# %%
tfidf = calculate_tfidf('google', index[480], index, inv_index)
print(f"TF-IDF слова 'google' в новости 480: {tfidf}")
# Out:
# TF-IDF слова 'google' в новости 480: 0.36599742710023275

# %% [markdown]
# <p class="task" id="5"></p>
#
# ### 5
# Используя собственную реализацию TD-IDF, закодируйте новости. Результатом должна являться матрица `MxN`, где `M` - количество новостей в корпусе, `N` - размер обратного индекса. Выведите форму полученной матрицы на экран.

# %%
tfidf_matrix = []

for doc_id, tokens in index.items():
    tfidf_vector = []

    for word in inv_index.keys():
        tfidf_score = calculate_tfidf(word, index[doc_id], index, inv_index)
        tfidf_vector.append(tfidf_score)
        
    tfidf_matrix.append(tfidf_vector)

# %%
np.array(tfidf_matrix).shape
# Out:
# (500, 2443)

# %% [markdown]
# <p class="task" id="6"></p>
#
# ### 6
# Для заданного текста новости найдите топ-3 наиболее похожих новости, воспользовавшись матрицей TD-IDF из предыдущего задания. Для определения схожести используйте функцию косинусного расстояния. Выведите на экран текст найденных новостей и значение метрики близости для каждой новости.

# %%
example = "Жириновский предложил перенести столицу из Москвы"

# %%
example_tokens = []
for token in word_tokenize(example):
    example_tokens.append(morph.parse(token)[0].normal_form)  
example_tokens
# Out:
# ['жириновский', 'предложить', 'перенести', 'столица', 'из', 'москва']

# %%
example_tfidf = []

for word in inv_index.keys():
    tfidf_score = calculate_tfidf(word, example_tokens, index, inv_index)
    example_tfidf.append(tfidf_score)

len(example_tfidf)
# Out:
# 2443

# %%
cosine_similarities = cosine_similarity([example_tfidf], tfidf_matrix)

cosine_similarities = cosine_similarities[0]

top_indices = np.argsort(cosine_similarities)[-3:][::-1]

for idx in top_indices:
    similarity_value = cosine_similarities[idx]
    vector = tfidf_matrix[idx]
    print(f"Новость номер {idx} : '{corpus[idx]}', косинусное сходство: {similarity_value}\n")
# Out:
# Новость номер 9 : 'трамп предложил перенести новые санкции против россии из за дня народного единства ', косинусное сходство: 0.2791459281886526
#
# Новость номер 78 : '31 декабря владимир жириновский предложит имя своего преемника ', косинусное сходство: 0.23237550223962905
#
# Новость номер 330 : 'в госдуме зарегистрирован законопроект о переносе столицы россии в великий новгород ', косинусное сходство: 0.22909198817042312

# %% [markdown]
# <p class="task" id="7"></p>
#
# ### 7
# Для заданного текста новости найдите топ-3 наиболее похожих новости, воспользовавшись собственной реализацией функции ранжирования [BM25](https://en.wikipedia.org/wiki/Okapi_BM25). Выведите на экран текст найденных новостей и значение метрики ранжирования для каждой новости.

# %%
example = "Жириновский предложил перенести столицу из Москвы"

# %% [markdown]
# ## Обратная связь
# - [ ] Хочу получить обратную связь по решению
